# %%
import pandas as pd
import numpy as np
from tqdm import tqdm

# %%
org = pd.read_csv('mustHaveSkills-2.csv', header = 0, encoding='ISO-8859-1', low_memory=False)
org.head()
# Out:
#    job_brief_id keyword_name             job_title
# 0             4          PHP          Web Designer
# 1             4          PHP         Web Developer
# 2             4          PHP  Full Stack Developer
# 3             4          PHP               Dev Ops
# 4             4          PHP       Product Manager

# %%
dataset = pd.read_csv('skill2vec_50K.csv', header = 0, encoding='ISO-8859-1', low_memory=False)
dataset.head()
# Out:
#     14463             Rest       Communication Skills           Geo Fencing  \
# 0    9153  capital_markets                    lending     trading_solutions
# 1   45150              r12  good communication skills         communication
# 2   32055        quotation                      email                   fax
# 3   47796            prime               HMC Operator  hmc machine operator
# 4  117774               L3                 Facilities          Team Leading
#
#                Core Java         Android SDK          Web Services  \
# 0     financial_services  investment_banking  front_office_trading
# 1  functional consultant              oracle           oracle apps
# 2    customer complaints           follow up      customer support
# 3                   HAAS               Fanuc           HMC Machine
# 4               Archibus              Hiring               Tririga
#
#                      SOAP     Web Technologies      Payment Gateway  ...  \
# 0  advertising_technology              ad_tech        digital_video  ...
# 1                     scm  oracle applications                 ascp  ...
# 2        order processing      data management  database management  ...
# 3           Cutting Tools       2D Programming                  ITI  ...
# 4                     NaN                  NaN                  NaN  ...
#
#   Unnamed: 951 Unnamed: 952 Unnamed: 953 Unnamed: 954 Unnamed: 955  \
# 0          NaN          NaN          NaN          NaN          NaN
# 1          NaN          NaN          NaN          NaN          NaN
# 2          NaN          NaN          NaN          NaN          NaN
# 3          NaN          NaN          NaN          NaN          NaN
# 4          NaN          NaN          NaN          NaN          NaN
#
#   Unnamed: 956 Unnamed: 957 Unnamed: 958 Unnamed: 959 Unnamed: 960
# 0          NaN          NaN          NaN          NaN          NaN
# 1          NaN          NaN          NaN          NaN          NaN
# 2          NaN          NaN          NaN          NaN          NaN
# 3          NaN          NaN          NaN          NaN          NaN
# 4          NaN          NaN          NaN          NaN          NaN
#
# [5 rows x 961 columns]

# %%
data = []
for index, row in tqdm(dataset.iterrows()):
    job_brief_id = row[0]
    keyword_name = row[1]
    job_titles = []
#     print(job_brief_id)
#     print(keyword_name)
    
    row = row.drop(row.index[0]) # remove job_brief_id
    row = row.drop(row.index[0]) # remove keyword_name
    for item in row:
        if str(item) != "nan":
            curr_row = []
            curr_row.append(job_brief_id)
            curr_row.append(keyword_name)
            curr_row.append(item)
            data.append(curr_row)
# Out:
# 999it [00:02, 477.62it/s]

# %%
data
# Out:
# [[9153, 'capital_markets', 'lending'],
#  [9153, 'capital_markets', 'trading_solutions'],
#  [9153, 'capital_markets', 'financial_services'],
#  [9153, 'capital_markets', 'investment_banking'],
#  [9153, 'capital_markets', 'front_office_trading'],
#  [9153, 'capital_markets', 'advertising_technology'],
#  [9153, 'capital_markets', 'ad_tech'],
#  [9153, 'capital_markets', 'digital_video'],
#  [9153, 'capital_markets', 'digital_media'],
#  [9153, 'capital_markets', 'display'],
#  [9153, 'capital_markets', 'mobile'],
#  [9153, 'capital_markets', 'video'],
#  [9153, 'capital_markets', 'social'],
#  [9153, 'capital_markets', 'custom_content'],
#  [9153, 'capital_markets', 'banking'],
#  [9153, 'capital_markets', 'software'],
#  [9153, 'capital_markets', 'sales'],
#  [9153, 'capital_markets', 'new_business_development'],
#  [9153, 'capital_markets', 'financial'],
#  [9153, 'capital_markets', 'finance'],
#  [9153, 'capital_markets', 'fis'],
#  [9153, 'capital_markets', 'bank'],
#  [9153, 'capital_markets', 'healthcare'],
#  [9153, 'capital_markets', 'health_services'],
#  [9153, 'capital_markets', 'pharmaceuticals'],
#  [9153, 'capital_markets', 'life_science'],
#  [9153, 'capital_markets', 'lifescience'],
#  [45150, 'r12', 'good communication skills'],
#  [45150, 'r12', 'communication'],
#  [45150, 'r12', 'functional consultant'],
#  [45150, 'r12', 'oracle'],
#  [45150, 'r12', 'oracle apps'],
#  [45150, 'r12', 'scm'],
#  [45150, 'r12', 'oracle applications'],
#  [45150, 'r12', 'ascp'],
#  [45150, 'r12', 'modules'],
#  [32055, 'quotation', 'email'],
#  [32055, 'quotation', 'fax'],
#  [32055, 'quotation', 'customer complaints'],
#  [32055, 'quotation', 'follow up'],
#  [32055, 'quotation', 'customer support'],
#  [32055, 'quotation', 'order processing'],
#  [32055, 'quotation', 'data management'],
#  [32055, 'quotation', 'database management'],
#  [32055, 'quotation', 'sales support'],
#  [47796, 'prime', 'HMC Operator'],
#  [47796, 'prime', 'hmc machine operator'],
#  [47796, 'prime', 'HAAS'],
#  [47796, 'prime', 'Fanuc'],
#  [47796, 'prime', 'HMC Machine'],
#  [47796, 'prime', 'Cutting Tools'],
#  [47796, 'prime', '2D Programming'],
#  [47796, 'prime', 'ITI'],
#  [47796, 'prime', 'Diploma'],
#  [47796, 'prime', 'HMC'],
#  [47796, 'prime', 'Ahmedabad'],
#  [47796, 'prime', 'Gujarat'],
#  [47796, 'prime', 'Odhav'],
#  [47796, 'prime', 'Vatva'],
#  [47796, 'prime', 'Naroda'],
#  [47796, 'prime', 'Rakhial'],
#  [47796, 'prime', 'Kathwada'],
#  [47796, 'prime', 'Narol'],
#  [47796, 'prime', 'Nikol'],
#  [47796, 'prime', 'Bapunagar'],
#  [47796, 'prime', 'vmc operator'],
#  [47796, 'prime', 'CNC Operator'],
#  [47796, 'prime', 'CNC'],
#  [47796, 'prime', 'VMC'],
#  [117774, 'L3', 'Facilities'],
#  [117774, 'L3', 'Team Leading'],
#  [117774, 'L3', 'Archibus'],
#  [117774, 'L3', 'Hiring'],
#  [117774, 'L3', 'Tririga'],
#  [99315, 'SCOPE', 'Financial Analysis'],
#  [99315, 'SCOPE', 'Policy Development'],
#  [99315, 'SCOPE', 'Management Skills'],
#  [99315, 'SCOPE', 'Finance'],
#  [99315, 'SCOPE', 'Accounting'],
#  [99315, 'SCOPE', 'Project Management'],
#  [99315, 'SCOPE', 'Focus'],
#  [99315, 'SCOPE', 'Process Improvement'],
#  [99315, 'SCOPE', 'Business Administration'],
#  [34110, 'Machine Shop', 'Quality control'],
#  [34110, 'Machine Shop', 'PPAP'],
#  [113132, 'Civil Works', 'Civil Engineer'],
#  [113132, 'Civil Works', 'Civil'],
#  [113132, 'Civil Works', 'Civil Engineering'],
#  [43736, 'System Verilog', 'VHDL'],
#  [43736, 'System Verilog', 'EDA Tools'],
#  [43736, 'System Verilog', 'Verification'],
#  [43736, 'System Verilog', 'Design'],
#  [43736, 'System Verilog', 'Test Planning'],
#  [43736, 'System Verilog', 'Magellan'],
#  [43736, 'System Verilog', 'QuestaFormal'],
#  [222, 'solution', 'delivery'],
#  [222, 'solution', 'project_delivery'],
#  [222, 'solution', 'project_management'],
#  [222, 'solution', 'pmp'],
#  [222, 'solution', 'project_planning'],
#  [222, 'solution', 'pmo'],
#  [222, 'solution', 'stakeholder_management'],
#  [222, 'solution', 'stingray'],
#  [222, 'solution', 'riverbed'],
#  [222, 'solution', 'wan_optimization'],
#  [222, 'solution', 'central_management_console'],
#  [222, 'solution', 'opnet'],
#  [222, 'solution', 'granite'],
#  [222, 'solution', 'accountability'],
#  [222, 'solution', 'cross-functional'],
#  [222, 'solution', 'strategy'],
#  [222, 'solution', 'mentorship'],
#  [222, 'solution', 'communication_skills'],
#  [222, 'solution', 'decision-making'],
#  [222, 'solution', 'best_practices'],
#  [222, 'solution', 'documentation'],
#  [222, 'solution', 'procedure'],
#  [222, 'solution', 'integration'],
#  [222, 'solution', 'production'],
#  [222, 'solution', 'sdlc'],
#  [222, 'solution', 'leadership'],
#  [222, 'solution', 'partnership'],
#  [222, 'solution', 'collaboration'],
#  [222, 'solution', 'management_consulting'],
#  [222, 'solution', 'finance'],
#  [222, 'solution', 'facilitation'],
#  [32363, 'Cyber Threat Management', 'Technology strategy development'],
#  [32363, 'Cyber Threat Management', 'COBIT'],
#  [32363, 'Cyber Threat Management', 'Project Management'],
#  [32363, 'Cyber Threat Management', 'Operations'],
#  [32363, 'Cyber Threat Management', 'CISSP'],
#  [32363, 'Cyber Threat Management', 'PMP'],
#  [32363, 'Cyber Threat Management', 'ITIL'],
#  [80266, 'oracle', 'oracle pl / sql'],
#  [80266, 'oracle', 'oracle plsql'],
#  [80266, 'oracle', 'plsql'],
#  [80266, 'oracle', 'pl / sql'],
#  [80266, 'oracle', 'sql'],
#  [80266, 'oracle', 'oracle 10g'],
#  [80266, 'oracle', 'oracle 11i'],
#  [80266, 'oracle', 'reports'],
#  [80266, 'oracle', 'forms'],
#  [80266, 'oracle', 'tables'],
#  [80266, 'oracle', 'Performance Tuning'],
#  [80266, 'oracle', 'Data Modeling'],
#  [51343, 'FRUAD ANALYST', 'KYC'],
#  [51343, 'FRUAD ANALYST', 'COMPLIANCE'],
#  [51343, 'FRUAD ANALYST', 'PROCESS ASSOCIATE'],
#  [51343, 'FRUAD ANALYST', 'PROCESS EXECUTIVE'],
#  [51343, 'FRUAD ANALYST', 'CREDIT ANALYSIS'],
#  [51343, 'FRUAD ANALYST', 'FRESHERS'],
#  [51343, 'FRUAD ANALYST', 'Client Servicing'],
#  [51343, 'FRUAD ANALYST', 'RISK ANALYST'],
#  [51343, 'FRUAD ANALYST', 'RISK ANALYSIS'],
#  [51343, 'FRUAD ANALYST', 'AML'],
#  [51343, 'FRUAD ANALYST', 'CUSTOMER SERVICE'],
#  [51343, 'FRUAD ANALYST', 'CUSTOMER SUPPORT'],
#  [51343, 'FRUAD ANALYST', 'CSO'],
#  [51343, 'FRUAD ANALYST', 'CSE'],
#  [51343, 'FRUAD ANALYST', 'CSR'],
#  [51343, 'FRUAD ANALYST', 'ECOMMERCE'],
#  [51343, 'FRUAD ANALYST', 'AMAZON'],
#  [51343, 'FRUAD ANALYST', 'FLIPKART'],
#  [6885, 'adobe', 'experience'],
#  [6885, 'adobe', 'manager'],
#  [6885, 'adobe', 'adobe_cq'],
#  [6885, 'adobe', 'wcm'],
#  [6885, 'adobe', 'apache_jackrabbit'],
#  [6885, 'adobe', 'dam'],
#  [6885, 'adobe', 'web_content_management'],
#  [6885, 'adobe', 'digital_asset_management'],
#  [6885, 'adobe', 'apache_felix'],
#  [6885, 'adobe', 'java_servlets'],
#  [6885, 'adobe', 'jsp'],
#  [6885, 'adobe', 'json'],
#  [6885, 'adobe', 'requirements_engineering'],
#  [6885, 'adobe', 'api'],
#  [6885, 'adobe', 'apache_sling'],
#  [6885, 'adobe', 'javamail'],
#  [6885, 'adobe', 'google_search_appliance'],
#  [6885, 'adobe', 'document_processing'],
#  [6885, 'adobe', 'content_development'],
#  [6885, 'adobe', 'search_engines'],
#  [6885, 'adobe', 'adobe_sitecatalyst'],
#  [6885, 'adobe', 'web_analytics'],
#  [6885, 'adobe', 'adobe_analytics'],
#  [6885, 'adobe', 'saint'],
#  [6885, 'adobe', 'adobe_livecycle'],
#  [6885, 'adobe', 'osgi'],
#  [6885, 'adobe', 'apache_avro'],
#  [6885, 'adobe', 'apache_thrift'],
#  [6885, 'adobe', 'rcp'],
#  [6885, 'adobe', 'swt'],
#  [6885, 'adobe', 'amazon_simpledb'],
#  [17829, 'Daily Operations', 'Technical Management'],
#  [17829, 'Daily Operations', 'Incident Management'],
#  [17829, 'Daily Operations', 'Staff Management'],
#  [17829, 'Daily Operations', 'Networking'],
#  [17829, 'Daily Operations', 'Telecom'],
#  [17829, 'Daily Operations', 'Operations Management'],
#  [17829, 'Daily Operations', 'People Management'],
#  [17829, 'Daily Operations', 'Process Development'],
#  [17829, 'Daily Operations', 'Network Elements'],
#  [93530, 'seo optimization', 'SMO manager'],
#  [93530, 'seo optimization', 'sem optimization'],
#  [93530, 'seo optimization', 'SEO'],
#  [93530, 'seo optimization', 'SMO'],
#  [93530, 'seo optimization', 'Blogs'],
#  [93530, 'seo optimization', 'Technical Architecture'],
#  [93530, 'seo optimization', 'Search engine optimization'],
#  [93530, 'seo optimization', 'search engine marketing'],
#  [93530, 'seo optimization', 'pay per click'],
#  [93530, 'seo optimization', 'social media optimization'],
#  [93530, 'seo optimization', 'Blogging'],
#  [4795, 'gcd', 'mapkit'],
#  [4795, 'gcd', 'cocoa_touch'],
#  [4795, 'gcd', 'xcode'],
#  [4795, 'gcd', 'objective-c'],
#  [4795, 'gcd', 'sqlite'],
#  [4795, 'gcd', 'pair_programming'],
#  [4795, 'gcd', 'core_data'],
#  [4795, 'gcd', 'animation'],
#  [4795, 'gcd', 'concurrent_computing'],
#  [4795, 'gcd', 'mingle'],
#  [4795, 'gcd', 'netscout'],
#  [4795, 'gcd', 'quartz'],
#  [4795, 'gcd', 'uikit'],
#  [4795, 'gcd', 'webkit'],
#  [4795, 'gcd', 'webobjects'],
#  [4795, 'gcd', 'opengl_es'],
#  [4795, 'gcd', 'conceptualization'],
#  [4795, 'gcd', 'ide'],
#  [4795, 'gcd', 'cocoa'],
#  [4795, 'gcd', 'color_management'],
#  [4795, 'gcd', 'applescript'],
#  [4795, 'gcd', 'design_patterns'],
#  [4795, 'gcd', 'jamf_casper_suite'],
#  [4795, 'gcd', 'ipo'],
#  [4795, 'gcd', 'ios'],
#  [4795, 'gcd', 'mobile_devices'],
#  [4795, 'gcd', 'mobile_technology'],
#  [4795, 'gcd', 'blackberry'],
#  [4795, 'gcd', 'microsoft_windows_phone'],
#  [4795, 'gcd', 'xamarin'],
#  [23665, 'english', 'strong interpersonal skills'],
#  [23665, 'english', 'team skills'],
#  [23665, 'english', 'international markets'],
#  [23665, 'english', 'emailing'],
#  [23665, 'english', 'result oriented'],
#  [23665, 'english', 'database building'],
#  [23665, 'english', 'cold calling'],
#  [23665, 'english', 'business development executive'],
#  [23665, 'english', 'lead generation'],
#  [116587, 'development', 'functional testing'],
#  [116587, 'development', 'test cases'],
#  [116587, 'development', 'oracle'],
#  [116587, 'development', 'sql server'],
#  [116587, 'development', 'rdbms'],
#  [116587, 'development', 'testing tools'],
#  [116587, 'development', 'selenium'],
#  [116587, 'development', 'product management'],
#  [116587, 'development', 'computer science'],
#  [54316, 'IP Networking', 'Netapp'],
#  [54316, 'IP Networking', 'IBM SAN'],
#  [54316, 'IP Networking', 'Legato'],
#  [54316, 'IP Networking', 'EMC'],
#  [54316, 'IP Networking', 'Linux'],
#  [54316, 'IP Networking', 'Storage'],
#  [54316, 'IP Networking', 'Windows'],
#  [54316, 'IP Networking', 'Unix'],
#  [54316, 'IP Networking', 'TCP'],
#  [2323, 'ultipro', 'ccrc'],
#  [2323, 'ultipro', 'ibm_build_forge'],
#  [2323, 'ultipro', 'nant'],
#  [2323, 'ultipro', 'ibm_rational_clearcase'],
#  [2323, 'ultipro', 'release_engineering'],
#  [2323, 'ultipro', 'vehicle_insurance'],
#  [2323, 'ultipro', 'hr_management_system'],
#  [2323, 'ultipro', 'adp_payroll'],
#  [2323, 'ultipro', 'payroll'],
#  [2323, 'ultipro', 'workday'],
#  [2323, 'ultipro', 'hr_management'],
#  [2323, 'ultipro', 'report_writing'],
#  [2323, 'ultipro', 'hr_management_system_administration'],
#  [2323, 'ultipro', 'data_flow'],
#  [2323, 'ultipro', 'employee_self-service'],
#  [2323, 'ultipro', 'talent_management'],
#  [2323, 'ultipro', 'system_implementation'],
#  [2323, 'ultipro', 'kenexa'],
#  [2323, 'ultipro', 'data_integrity'],
#  [2323, 'ultipro', 'data_analysis'],
#  [2323, 'ultipro', 'database'],
#  [2323, 'ultipro', 'procedure'],
#  [2323, 'ultipro', 'analytical_skill'],
#  [2323, 'ultipro', 'sql'],
#  [2323, 'ultipro', 'human_resources'],
#  [2323, 'ultipro', 'job_boards'],
#  [2323, 'ultipro', 'shared_services'],
#  [2323, 'ultipro', 'organizational_architecture'],
#  [2323, 'ultipro', 'coaching'],
#  [2323, 'ultipro', 'oracle_hr'],
#  [9213, 'rfic', 'radifrequency_integrated_circuit'],
#  [9213, 'rfic', 'ic'],
#  [9213, 'rfic', 'ics'],
#  [9213, 'rfic', 'integrated_circuit'],
#  [9213, 'rfic', 'cellular_receivers'],
#  [9213, 'rfic', 'spectre_rf'],
#  [9213, 'rfic', 'rf_design'],
#  [9213, 'rfic', 'rf_tranceivers'],
#  [9213, 'rfic', 'rf'],
#  [9213, 'rfic', 'transceivers'],
#  [9213, 'rfic', 'transceiver'],
#  [35942, 'Moulds', 'Injection Moulding'],
#  [35942, 'Moulds', 'Plastic'],
#  [35942, 'Moulds', 'plastic moulding'],
#  [35942, 'Moulds', 'plastic injection moulding'],
#  [80802, 'joomla', 'ajax'],
#  [80802, 'joomla', 'jquery'],
#  [80802, 'joomla', 'wordpress'],
#  [80802, 'joomla', 'magento'],
#  [80802, 'joomla', 'cakephp'],
#  [80802, 'joomla', 'php mysql'],
#  [80802, 'joomla', 'coding'],
#  [80802, 'joomla', 'api'],
#  [80802, 'joomla', 'usability'],
#  [127127, '2016 passed out', 'Fresher'],
#  [127127, '2016 passed out', 'graduate fresher'],
#  [127127, '2016 passed out', 'SQL'],
#  [127127, '2016 passed out', 'unix'],
#  [127127, '2016 passed out', 'Linux'],
#  [127127, '2016 passed out', 'trainee'],
#  [78754, 'openstack', 'Python Scripting'],
#  [78754, 'openstack', 'Open Stack'],
#  [78754, 'openstack', 'Python'],
#  [37096, 'Functional', 'Communication Skills'],
#  [37096, 'Functional', 'SQL Server'],
#  [37096, 'Functional', '.Net'],
#  [37096, 'Functional', 'IIS'],
#  [37096, 'Functional', 'Oracle'],
#  [37096, 'Functional', 'Production Support'],
#  [37096, 'Functional', 'Problem Solving'],
#  [33675, 'analytics', 'gis'],
#  [33675, 'analytics', 'expert'],
#  [33675, 'analytics', 'experts'],
#  [33675, 'analytics', 'projects'],
#  [33675, 'analytics', 'do'],
#  [33675, 'analytics', 'managing'],
#  [33675, 'analytics', 'data analysts'],
#  [33675, 'analytics', 'database'],
#  [33675, 'analytics', 'software'],
#  [63893, 'Lead Trainer', 'Process trainer'],
#  [63893, 'Lead Trainer', 'Trainer'],
#  [63893, 'Lead Trainer', 'training'],
#  [63893, 'Lead Trainer', 'Learning &amp; Development'],
#  [92418, 'OO ABAP', 'WebDynpro'],
#  [92418, 'OO ABAP', 'SAP'],
#  [92418, 'OO ABAP', 'FICO'],
#  [92418, 'OO ABAP', 'ECC'],
#  [92418, 'OO ABAP', 'ABAP'],
#  [92418, 'OO ABAP', 'UI Design'],
#  [80769, 'joomla', 'chat'],
#  [80769, 'joomla', 'experience'],
#  [80769, 'joomla', 'project'],
#  [80769, 'joomla', 'code'],
#  [80769, 'joomla', 'php'],
#  [80769, 'joomla', 'cms'],
#  [80769, 'joomla', 'component development'],
#  [80769, 'joomla', 'e commerce'],
#  [80769, 'joomla', 'core php'],
#  [40429, 'buying', 'planning'],
#  [40429, 'buying', 'retail merchandising'],
#  [40429, 'buying', 'ms excel'],
#  [9997, 'JSON', 'Data Modeling'],
#  [9997, 'JSON', 'SDLC'],
#  [9997, 'JSON', 'SSIS'],
#  [9997, 'JSON', 'Sql Tuning'],
#  [9997, 'JSON', 'w3c'],
#  [9997, 'JSON', 'AJAX'],
#  [9997, 'JSON', 'C#'],
#  [76496, 'MIS Preparation', 'Excel'],
#  [76496, 'MIS Preparation', 'ERP System'],
#  [84794, 'Product Owner', 'iterative development'],
#  [84794, 'Product Owner', 'User Acceptance Testing'],
#  [84794, 'Product Owner', 'PL'],
#  [84794, 'Product Owner', 'SQL'],
#  [84794, 'Product Owner', 'SQL Developer'],
#  [84794, 'Product Owner', 'technical writing'],
#  [98741, 'software product development', 'java programming'],
#  [98741, 'software product development', 'client interaction'],
#  [98741, 'software product development', 'excellent communication'],
#  [98741, 'software product development', 'core java'],
#  [98741, 'software product development', 'server'],
#  [98741, 'software product development', 'data structures'],
#  [98741, 'software product development', 'web development'],
#  [98741, 'software product development', 'object oriented programming'],
#  [98741, 'software product development', 'release engineering'],
#  [60897, 'Customer Satisfaction', 'graduate fresher'],
#  [60897, 'Customer Satisfaction', 'fresher female'],
#  [60897, 'Customer Satisfaction', 'telecaller female'],
#  [60897, 'Customer Satisfaction', 'telesales telemarketing'],
#  [60897, 'Customer Satisfaction', 'Customer Service'],
#  [60897, 'Customer Satisfaction', 'customer care executive'],
#  [60897, 'Customer Satisfaction', 'cce'],
#  [60897, 'Customer Satisfaction', 'csa'],
#  [60897, 'Customer Satisfaction', 'customer service associate'],
#  [60897, 'Customer Satisfaction', 'customer service representative'],
#  [60897, 'Customer Satisfaction', 'customer service executive'],
#  [115414, 'Net', '.Net'],
#  [115414, 'Net', 'Technical Support'],
#  [115414, 'Net', 'Non Voice'],
#  [47659, 'build and release', 'Rational team concert'],
#  [47659, 'build and release', 'jenkins'],
#  [47659, 'build and release', 'SCM RTC'],
#  [47659, 'build and release', 'RTC'],
#  [47659, 'build and release', 'Clearcase'],
#  [100961, 'electronics', 'hardware'],
#  [100961, 'electronics', 'MS project'],
#  [100961, 'electronics', 'PMP'],
#  [8526, 'java', 'j2ee'],
#  [8526, 'java', 'j2se'],
#  [8526, 'java', 'jee'],
#  [8526, 'java', 'j2me'],
#  [8526, 'java', 'javase'],
#  [8526, 'java', 'javame'],
#  [8526, 'java', 'javaseb'],
#  [8526, 'java', 'c++'],
#  [8526, 'java', 'c#'],
#  [8526, 'java', 'c'],
#  [8526, 'java', 'javascript'],
#  [8526, 'java', 'java_script'],
#  [8526, 'java', 'js'],
#  [8526, 'java', 'java-script'],
#  [8526, 'java', 'jquery'],
#  [8526, 'java', 'full_stack'],
#  [8526, 'java', 'fullstack'],
#  [8526, 'java', 'html5'],
#  [8526, 'java', 'bootstrap'],
#  [8526, 'java', 'js_framework'],
#  [8526, 'java', 'javascript_framework'],
#  [8526, 'java', 'distributed_systems'],
#  [8526, 'java', 'distributed_system'],
#  [8526, 'java', 'big_data'],
#  [8526, 'java', 'machine_learning'],
#  [8526, 'java', 'web_services'],
#  [8526, 'java', 'hadoop'],
#  [8526, 'java', 'mapreduce'],
#  [8526, 'java', 'map-reduce'],
#  [8526, 'java', 'large_scale'],
#  [8526, 'java', 'parallel_programming'],
#  [8526, 'java', 'data_analytics'],
#  [8526, 'java', 'data_mining'],
#  [8526, 'java', 'math'],
#  [8526, 'java', 'statistics'],
#  [8526, 'java', 'javaee'],
#  [8526, 'java', 'j2seb'],
#  [8526, 'java', 'odesign'],
#  [8526, 'java', 'object-oriented_design'],
#  [8526, 'java', 'object_oriented_design'],
#  [8526, 'java', 'objectoriented_design'],
#  [8526, 'java', 'python'],
#  [8526, 'java', 'back_end'],
#  [8526, 'java', 'stream_processing'],
#  [8526, 'java', 'data'],
#  [8526, 'java', 'scala'],
#  [8526, 'java', 'spark'],
#  [8526, 'java', 'application'],
#  [8526, 'java', 'platform'],
#  [8526, 'java', 'oracle'],
#  [8526, 'java', 'mysql'],
#  [8526, 'java', 'linux'],
#  [8526, 'java', 'ant'],
#  [8526, 'java', 'maven'],
#  [8526, 'java', 'subversion'],
#  [8526, 'java', 'git'],
#  [8526, 'java', 'webscale'],
#  [8526, 'java', 'availability'],
#  [8526, 'java', 'monitoring'],
#  [8526, 'java', 'docker'],
#  [8526, 'java', 'mobile_games'],
#  [8526, 'java', 'mobile_game'],
#  [8526, 'java', 'mobile_gaming'],
#  [8526, 'java', 'oop'],
#  [8526, 'java', 'object-oriented_programming'],
#  [8526, 'java', 'object_oriented_programming'],
#  [8526, 'java', 'object_oriented'],
#  [8526, 'java', 'e_commerce'],
#  [8526, 'java', 'e-commerce'],
#  [8526, 'java', 'online_retail'],
#  [8526, 'java', 'payment_solutions'],
#  [8526, 'java', 'online_payments'],
#  [8526, 'java', 'pricing'],
#  [8526, 'java', 'imagery'],
#  [8526, 'java', 'finance'],
#  [8526, 'java', 'product_catalog'],
#  [8526, 'java', 'algorithm'],
#  [8526, 'java', 'data_structures'],
#  [8526, 'java', 'data_structure'],
#  [8526, 'java', 'design'],
#  [8526, 'java', 'cache'],
#  [8526, 'java', 'server'],
#  [8526, 'java', 'nfv'],
#  [8526, 'java', 'sdn'],
#  [8526, 'java', 'cloud'],
#  [8526, 'java', 'virtualization'],
#  [8526, 'java', 'open_stack'],
#  [8526, 'java', 'android'],
#  [8526, 'java', 'ios'],
#  [8526, 'java', 'restful'],
#  [8526, 'java', 'rest'],
#  [8526, 'java', 'api'],
#  [8526, 'java', 'apis'],
#  [8526, 'java', 'soap'],
#  [8526, 'java', 'backend'],
#  [8526, 'java', 'back-end'],
#  [8526, 'java', 'management'],
#  [8526, 'java', 'web_development'],
#  [8526, 'java', 'online_games'],
#  [8526, 'java', 'dc/dc'],
#  [8526, 'java', 'power_optimizer'],
#  [8526, 'java', 'solar_power'],
#  [104918, 'knowledge', 'knowledge of c'],
#  [104918, 'knowledge', 'soa'],
#  [104918, 'knowledge', 'xml'],
#  [104918, 'knowledge', 'core java'],
#  [104918, 'knowledge', 'esb'],
#  [104918, 'knowledge', 'design and development'],
#  [104918, 'knowledge', 'object oriented design'],
#  [104918, 'knowledge', 'data structures'],
#  [104918, 'knowledge', 'api'],
#  [106610, 'ASP.Net', 'WCF'],
#  [106610, 'ASP.Net', 'WWF'],
#  [106610, 'ASP.Net', 'LINQ'],
#  [106610, 'ASP.Net', 'Windows Services'],
#  [106610, 'ASP.Net', 'WPF'],
#  [106610, 'ASP.Net', 'C#'],
#  [106610, 'ASP.Net', 'SQL Server'],
#  [106610, 'ASP.Net', 'VB.NET'],
#  [106610, 'ASP.Net', 'MVC'],
#  [106610, 'ASP.Net', '.Net Developer'],
#  [72892, 'passport', 'information technology'],
#  [72892, 'passport', 'outsourcing'],
#  [72892, 'passport', 'java'],
#  [72892, 'passport', 'offshore'],
#  [72892, 'passport', 'product development'],
#  [72892, 'passport', 'jms'],
#  [72892, 'passport', 'hiring'],
#  [72892, 'passport', 'coding'],
#  [72892, 'passport', 'travel'],
#  [16814, 'Party Reconciliation', 'Receipt'],
#  [16814, 'Party Reconciliation', 'Commerce'],
#  [16814, 'Party Reconciliation', 'Mall Operations'],
#  [16814, 'Party Reconciliation', 'Recovery accounts'],
#  [16814, 'Party Reconciliation', 'recovery accounts executive'],
#  [16814, 'Party Reconciliation', 'Finance'],
#  [16814, 'Party Reconciliation', 'Accounting'],
#  [16814, 'Party Reconciliation', 'Sales'],
#  [16814, 'Party Reconciliation', 'Account Management'],
#  [16814, 'Party Reconciliation', 'MIS Reporting'],
#  [16814, 'Party Reconciliation', 'Real Estate'],
#  [21964, 'NoSQL', 'Hadoop'],
#  [21964, 'NoSQL', 'MongoDB'],
#  [21964, 'NoSQL', 'SCALA'],
#  [21964, 'NoSQL', 'akka'],
#  [21964, 'NoSQL', 'kafka'],
#  [21964, 'NoSQL', 'cassandra'],
#  [21964, 'NoSQL', 'Java'],
#  [21964, 'NoSQL', 'Python'],
#  [21964, 'NoSQL', 'spark'],
#  [54252, 'IBM Case Manager', 'Case Manager'],
#  [48045, 'HR Generalist Activities', 'HRBP'],
#  [48045, 'HR Generalist Activities', 'HR Business Partner'],
#  [118436, 'excellent communication skills', 'willingness to learn'],
#  [118436, 'excellent communication skills', 'positive attitude'],
#  [118436, 'excellent communication skills', 'management'],
#  [118436, 'excellent communication skills', 'flexibility'],
#  [118436, 'excellent communication skills', 'sql'],
#  [118436, 'excellent communication skills', 'unix'],
#  [118436, 'excellent communication skills', 'production support'],
#  [118436, 'excellent communication skills', 'monitoring'],
#  [118436, 'excellent communication skills', 'night shifts'],
#  [88411, 'Receptionist Activities', 'Fro'],
#  [88411, 'Receptionist Activities', 'front office executive activities'],
#  [88411, 'Receptionist Activities', 'Front Office'],
#  [88411, 'Receptionist Activities', 'Calls'],
#  [88411, 'Receptionist Activities', 'Emails'],
#  [88411, 'Receptionist Activities', 'Sales Coordination'],
#  [88411, 'Receptionist Activities', 'Admin'],
#  [88411, 'Receptionist Activities', 'Sales'],
#  [88411, 'Receptionist Activities', 'Epbax'],
#  [110094, 'Cyber Security', 'IT risk'],
#  [110094, 'Cyber Security', 'IT audit'],
#  [110094, 'Cyber Security', 'information security audit'],
#  [110094, 'Cyber Security', 'itgc'],
#  [110094, 'Cyber Security', 'cisa'],
#  [110094, 'Cyber Security', 'information technology audit'],
#  [110094, 'Cyber Security', 'system audit'],
#  [79117, 'Quality Assurance', 'Customer Quality'],
#  [79117, 'Quality Assurance', 'QMS'],
#  [79117, 'Quality Assurance', 'Quality Engineering'],
#  [79117, 'Quality Assurance', 'Auditing'],
#  [79117, 'Quality Assurance', 'Marketing'],
#  [79117, 'Quality Assurance', 'Quality Systems'],
#  [79117, 'Quality Assurance', 'Process Audit'],
#  [79117, 'Quality Assurance', 'ISO 9001'],
#  [79117, 'Quality Assurance', 'Product Quality'],
#  [79117, 'Quality Assurance', 'Business Excellence'],
#  [79117, 'Quality Assurance', 'Business process development'],
#  [121297, 'Selling Skills', 'Mass Mailing'],
#  [121297, 'Selling Skills', 'Sales'],
#  [121297, 'Selling Skills', 'Direct Marketing'],
#  [121297, 'Selling Skills', 'Life Insurance'],
#  [102285, 'good communication skills', 'speak english'],
#  [102285, 'good communication skills', 'implementation'],
#  [102285, 'good communication skills', 'support'],
#  [102285, 'good communication skills', 'experience'],
#  [102285, 'good communication skills', 'projects'],
#  [102285, 'good communication skills', 'language'],
#  [102285, 'good communication skills', 'java'],
#  [102285, 'good communication skills', 'plsql'],
#  [102285, 'good communication skills', 'consultant'],
#  [93375, 'json', 'java'],
#  [93375, 'json', 'j2ee'],
#  [93375, 'json', 'javascript'],
#  [93375, 'json', 'xml'],
#  [93375, 'json', 'html'],
#  [93375, 'json', 'jsp'],
#  [93375, 'json', 'application development'],
#  [93375, 'json', 'user interface'],
#  [93375, 'json', 'ui design'],
#  [12815, 'sales', 'Business Development'],
#  [12815, 'sales', 'products'],
#  [12815, 'sales', 'sales manager'],
#  [101259, 'AngularJS', 'Ruby on Rails'],
#  [101259, 'AngularJS', 'Ruby'],
#  [101259, 'AngularJS', 'Rails'],
#  [100797, 'ICC', 'ICC2'],
#  [100797, 'ICC', 'Innovus'],
#  [100797, 'ICC', 'P&amp;R'],
#  [100797, 'ICC', 'Timing Closure'],
#  [100797, 'ICC', 'SoC Encounter'],
#  [100797, 'ICC', 'First Encounter'],
#  [100797, 'ICC', 'IR Drop'],
#  [100797, 'ICC', 'PnR'],
#  [100797, 'ICC', 'DC Compiler'],
#  [100797, 'ICC', 'RTL Compiler'],
#  [100797, 'ICC', 'RC'],
#  [100797, 'ICC', 'Prime Time'],
#  [100797, 'ICC', 'Physical Design'],
#  [100797, 'ICC', 'Signal Integrity'],
#  [100797, 'ICC', 'Synthesis'],
#  [100797, 'ICC', 'DC'],
#  [100797, 'ICC', 'Floor Planning'],
#  [100797, 'ICC', 'STA'],
#  [53368, 'us it staffing', 'us recruitment'],
#  [53368, 'us it staffing', 'us it recruitment'],
#  [111918, 'Inbound', 'Outbound'],
#  [111918, 'Inbound', 'Voice Process'],
#  [111918, 'Inbound', 'Hiring'],
#  [111918, 'Inbound', 'Interviewing'],
#  [111918, 'Inbound', 'Communication Skills'],
#  [111918, 'Inbound', 'Support Services'],
#  [111918, 'Inbound', 'CCE'],
#  [111918, 'Inbound', 'customer care executive'],
#  [111918, 'Inbound', 'csa'],
#  [111918, 'Inbound', 'bpo'],
#  [111918, 'Inbound', 'cse'],
#  [111918, 'Inbound', 'call center execuitve'],
#  [111918, 'Inbound', 'bpo execuitve'],
#  [111918, 'Inbound', 'inbound execuitve'],
#  [111918, 'Inbound', 'domestic bpo execuitve'],
#  [111918, 'Inbound', 'bpo fresher execuitve'],
#  [98229, 'configuration', 'google application deployment'],
#  [98229, 'configuration', 'deployment server'],
#  [98229, 'configuration', 'office 365 migration'],
#  [98229, 'configuration', 'office 365 deployment'],
#  [98229, 'configuration', 'office 365 implementation'],
#  [98229, 'configuration', 'Networking'],
#  [98229, 'configuration', 'Linux Administration'],
#  [98229, 'configuration', 'Open Source'],
#  [98229, 'configuration', 'Active Directory'],
#  [98229, 'configuration', 'deployment'],
#  [98229, 'configuration', 'migration'],
#  [98229, 'configuration', 'cloud computing'],
#  [80038, 'Technical Specifications', 'my sql server'],
#  [80038, 'Technical Specifications', 'oracle database9i'],
#  [80038, 'Technical Specifications', 'Oracle Development'],
#  [80038, 'Technical Specifications', 'Software Development'],
#  [80038, 'Technical Specifications', 'Oracle Database'],
#  [80038, 'Technical Specifications', '10g'],
#  [80038, 'Technical Specifications', 'oracle administration'],
#  [80038, 'Technical Specifications', 'oracle admin'],
#  [80038, 'Technical Specifications', 'oracle database admin'],
#  [80038, 'Technical Specifications', 'oracle dba'],
#  [107154, 'Web Technologies', 'data strategy'],
#  [107154, 'Web Technologies', 'resource modelling'],
#  [107154, 'Web Technologies', 'data management'],
#  [107154, 'Web Technologies', 'contact personalisation'],
#  [107154, 'Web Technologies', 'web analytics'],
#  [107154, 'Web Technologies', 'technical infrastructure'],
#  [107154, 'Web Technologies', 'CRM'],
#  [107154, 'Web Technologies', 'digital contact optimisation'],
#  [107154, 'Web Technologies', 'targeting'],
#  [92872, 'rollout', 'indian taxation'],
#  [92872, 'rollout', 'taxinn'],
#  [92872, 'rollout', 'condition types'],
#  [92872, 'rollout', 'pricing routines'],
#  [92872, 'rollout', 'standard sales cycle'],
#  [92872, 'rollout', 'SAP SD'],
#  [92872, 'rollout', 'sap sd consultant'],
#  [92872, 'rollout', 'sd consultant'],
#  [123910, 'User Interface Design', 'Design'],
#  [123910, 'User Interface Design', 'Angular.js'],
#  [123910, 'User Interface Design', 'HTML5'],
#  [123910, 'User Interface Design', 'CSS3'],
#  [123910, 'User Interface Design', 'jQuery'],
#  [73587, 'Zbrush', 'Texturing'],
#  [73587, 'Zbrush', 'Photoshop'],
#  [73587, 'Zbrush', 'Maya'],
#  [73587, 'Zbrush', '3D Modeling'],
#  [73587, 'Zbrush', 'Design'],
#  [50771, 'international sales', 'kyc'],
#  [50771, 'international sales', 'freshers'],
#  [50771, 'international sales', 'myntra'],
#  [50771, 'international sales', 'seller support'],
#  [50771, 'international sales', 'inside sales'],
#  [50771, 'international sales', 'e commerce'],
#  [50771, 'international sales', 'non voice'],
#  [50771, 'international sales', 'business development'],
#  [50771, 'international sales', 'flipkart'],
#  [50771, 'international sales', 'client servicing'],
#  [50771, 'international sales', 'sales'],
#  [50771, 'international sales', 'marketing'],
#  [50771, 'international sales', 'customer service'],
#  [50771, 'international sales', 'customer support'],
#  [50771, 'international sales', 'amazon'],
#  [50771, 'international sales', 'business analyst'],
#  [726, 'sap', 'tr'],
#  [89427, 'Region', 'Business Growth'],
#  [89427, 'Region', 'Sales Management'],
#  [89427, 'Region', 'Marketing Operations'],
#  [89427, 'Region', 'Business Development'],
#  [89427, 'Region', 'Key Account Management'],
#  [89427, 'Region', 'Marketing Management'],
#  [89427, 'Region', 'Business Operations'],
#  [89427, 'Region', 'Business Generation'],
#  [89427, 'Region', 'Profitability'],
#  [13510, 'NIM', 'HACMP'],
#  [13510, 'NIM', 'LPAR'],
#  [13510, 'NIM', 'HMC'],
#  [13510, 'NIM', 'Product Service'],
#  [13510, 'NIM', 'Aix'],
#  [13510, 'NIM', 'VIO'],
#  [13510, 'NIM', 'Java'],
#  [13510, 'NIM', 'Architectural Design'],
#  [13510, 'NIM', 'Oracle'],
#  [17113, 'assistant manager PED', 'am ped'],
#  [17113, 'assistant manager PED', 'asst manager ped'],
#  [17113, 'assistant manager PED', 'team leader ped'],
#  [17113, 'assistant manager PED', 'senior executive ped'],
#  [17113, 'assistant manager PED', 'team manager ped'],
#  [17113, 'assistant manager PED', 'assistant manager ped'],
#  [1195, 'parallel', 'computing'],
#  [1195, 'parallel', 'mpi'],
#  [1195, 'parallel', 'posix_threads'],
#  [1195, 'parallel', 'workload_analysis'],
#  [1195, 'parallel', 'code_optimization'],
#  [1195, 'parallel', 'cuda'],
#  [1195, 'parallel', 'high_performance_computing'],
#  [1195, 'parallel', 'openmp'],
#  [1195, 'parallel', 'distributed_file_system'],
#  [1195, 'parallel', 'xcat'],
#  [1195, 'parallel', 'numpy'],
#  [1195, 'parallel', 'econometrics'],
#  [1195, 'parallel', 'remote_direct_memory_access'],
#  [1195, 'parallel', 'mpp'],
#  [1195, 'parallel', 'vertica'],
#  [1195, 'parallel', 'emc_greenplum'],
#  [1195, 'parallel', 'bill_of_materials_management'],
#  [1195, 'parallel', 'netezza'],
#  [1195, 'parallel', 'hortonworks'],
#  [1195, 'parallel', 'hpc'],
#  [1195, 'parallel', 'computer_cluster_management'],
#  [1195, 'parallel', 'ddn'],
#  [1195, 'parallel', 'computer_cluster'],
#  [1195, 'parallel', 'computational_fluid_dynamics'],
#  [1195, 'parallel', 'cfd'],
#  [1195, 'parallel', 'fortran'],
#  [1195, 'parallel', 'mda'],
#  [1195, 'parallel', 'idl'],
#  [1195, 'parallel', 'physics'],
#  [1195, 'parallel', 'systems_modeling'],
#  [1195, 'parallel', 'mathematics'],
#  [57388, 'Taxation', 'Finance'],
#  [57388, 'Taxation', 'Auditing'],
#  [57388, 'Taxation', 'Accounting'],
#  [57388, 'Taxation', 'Internal Control'],
#  [57388, 'Taxation', 'Budgeting'],
#  [57388, 'Taxation', 'MIS Reporting'],
#  [57388, 'Taxation', 'Account Management'],
#  [57388, 'Taxation', 'Business Planning'],
#  [57388, 'Taxation', 'Due Diligence'],
#  [94123, 'internet information services', 'iis windows'],
#  [94123, 'internet information services', 'iis exchange'],
#  [94123, 'internet information services', 'iis storage'],
#  [94123, 'internet information services', 'iis desktop'],
#  [94123, 'internet information services', 'iis laptop'],
#  [94123, 'internet information services', 'iis admin'],
#  [94123, 'internet information services', 'iis administrator'],
#  [94123, 'internet information services', 'iis webserver admin'],
#  [94123, 'internet information services', 'iis webserver administration'],
#  [94123, 'internet information services', 'iis'],
#  [94123, 'internet information services', 'iis server'],
#  [94123, 'internet information services', 'iis administration'],
#  [94123, 'internet information services', 'Sql Tuning'],
#  [94123, 'internet information services', 'sql admin'],
#  [115287, 'NAGIOS', 'SSH'],
#  [115287, 'NAGIOS', 'Hadoop'],
#  [115287, 'NAGIOS', 'AWS'],
#  [115287, 'NAGIOS', 'Apache'],
#  [115287, 'NAGIOS', 'Ubuntu'],
#  [115287, 'NAGIOS', 'Fedora'],
#  [115287, 'NAGIOS', 'Linux Administration'],
#  [115287, 'NAGIOS', 'MySQL'],
#  [115287, 'NAGIOS', 'Redhat'],
#  [55288, 'ITI', 'diploma'],
#  [55288, 'ITI', 'fitter'],
#  [55288, 'ITI', 'industrial training institute'],
#  [55288, 'ITI', 'iti electrical'],
#  [55288, 'ITI', 'iti fitter'],
#  [55288, 'ITI', 'i.t.i.'],
#  [55288, 'ITI', 'electrician'],
#  [71500, 'Regional Sales', 'Marketing Support'],
#  [71500, 'Regional Sales', 'Btl'],
#  [71500, 'Regional Sales', 'Brand Building'],
#  [71500, 'Regional Sales', 'PR'],
#  [71500, 'Regional Sales', 'Events'],
#  [71500, 'Regional Sales', 'Activation'],
#  [71500, 'Regional Sales', 'CRM'],
#  [71500, 'Regional Sales', 'Strategy'],
#  [71500, 'Regional Sales', 'Agency Management'],
#  [62323, 'KAM', 'Reverse Logistics'],
#  [62323, 'KAM', 'Cycle count'],
#  [62323, 'KAM', 'reefer operation'],
#  [62323, 'KAM', 'temperature'],
#  [62323, 'KAM', 'Inventory'],
#  [62323, 'KAM', 'Tranportation'],
#  [62323, 'KAM', 'Warehouse'],
#  [62323, 'KAM', 'SCM'],
#  [62323, 'KAM', 'Cold Chain'],
#  [62323, 'KAM', 'Distribution'],
#  [120047, 'Company Secretary', 'CS'],
#  [17623, 'Business Development Power-(Transmission', 'Assistant Manager'],
#  [17623, 'Business Development Power-(Transmission', 'Distribution'],
#  [17623, 'Business Development Power-(Transmission', 'Substation)'],
#  [69149, 'marketing', 'business development'],
#  [69149, 'marketing', 'marketing planning'],
#  [69149, 'marketing', 'marketing strategy'],
#  [69149, 'marketing', 'executive assistant'],
#  [118566, 'W2', 'C2C'],
#  [118566, 'W2', 'H1B'],
#  [118566, 'W2', 'HR'],
#  [118566, 'W2', 'H1'],
#  [118566, 'W2', 'Workers Compensation'],
#  [118566, 'W2', 'Interviewing'],
#  [118566, 'W2', 'Staffing'],
#  [118566, 'W2', 'Hiring'],
#  [118566, 'W2', 'Payroll'],
#  [98100, 'Business Analysis', 'Research Analysis'],
#  [52825, 'General Ledger Accounting', 'Cash Management'],
#  [52825, 'General Ledger Accounting', 'ERP Functional'],
#  [52825, 'General Ledger Accounting', 'Accounts Receivable'],
#  [52825, 'General Ledger Accounting', 'Finance'],
#  [52825, 'General Ledger Accounting', 'Financial Accounting'],
#  [52825, 'General Ledger Accounting', 'Oracle ERP'],
#  [68357, 'International Taxation', 'Indian Gaap'],
#  [68357, 'International Taxation', 'Transfer Pricing Manager'],
#  [68357, 'International Taxation', 'Accounting Standards'],
#  [68357, 'International Taxation', 'Ca'],
#  [68357, 'International Taxation', 'Transfer Pricing'],
#  [68357, 'International Taxation', 'Chartered Accountant'],
#  [23431, 'FX', 'forex'],
#  [23431, 'FX', 'treasury'],
#  [75053, 'non tech sales', 'collection'],
#  [75053, 'non tech sales', '3rd party collection'],
#  [75053, 'non tech sales', '1st party collection'],
#  [75053, 'non tech sales', 'inbound sales'],
#  [75053, 'non tech sales', 'hardcore sales'],
#  [75053, 'non tech sales', 'visa sales'],
#  [75053, 'non tech sales', 'immigration selling'],
#  [75053, 'non tech sales', 'Sr. sales associate'],
#  [75053, 'non tech sales', 'Sales'],
#  [75053, 'non tech sales', 'Upselling'],
#  [75053, 'non tech sales', 'outbound sales'],
#  [75053, 'non tech sales', 'Sales executive'],
#  [75053, 'non tech sales', 'sales associate'],
#  [75053, 'non tech sales', 'sales officer'],
#  [21706, 'US Staffing', 'Client Acquisition'],
#  [58457, 'Customer support', 'customer executive'],
#  [58457, 'Customer support', 'customer care'],
#  [124217, 'VP Engineering', 'Algorithm'],
#  [124217, 'VP Engineering', 'data structures'],
#  [124217, 'VP Engineering', 'Object - Oriented Design'],
#  [124217, 'VP Engineering', 'technical solutions'],
#  [76104, 'Tele - Marketing', 'Call Center'],
#  [76104, 'Tele - Marketing', 'Tele - Sales'],
#  [76104, 'Tele - Marketing', 'Telemarketing'],
#  [30198, 'Java Web Services', 'XML'],
#  [30198, 'Java Web Services', 'Rest'],
#  [30198, 'Java Web Services', 'J2Ee'],
#  [30198, 'Java Web Services', 'JMS'],
#  [30198, 'Java Web Services', 'SOAP'],
#  [30198, 'Java Web Services', 'ESB'],
#  [30198, 'Java Web Services', 'Webmethods'],
#  [30198, 'Java Web Services', 'EAI'],
#  [30198, 'Java Web Services', 'Web Technologies'],
#  [65618, 'GC', 'HPLC'],
#  [65618, 'GC', 'UV'],
#  [65618, 'GC', 'AAS'],
#  [65618, 'GC', 'KF'],
#  [65618, 'GC', 'Finished good Analysis'],
#  [65618, 'GC', 'stability analysis'],
#  [76096, 'Equity', 'HNI Client Handling'],
#  [76096, 'Equity', 'Heading Branch'],
#  [76096, 'Equity', 'Relationship Management'],
#  [76096, 'Equity', 'Stock Broking'],
#  [76096, 'Equity', 'Client Acquisition'],
#  [76096, 'Equity', 'equity sales'],
#  [59457, 'Rest API', 'Java'],
#  [59457, 'Rest API', 'Spring'],
#  [59457, 'Rest API', 'Hibernate'],
#  [59457, 'Rest API', 'Maven'],
#  [59457, 'Rest API', 'J2EE'],
#  [108596, 'project management skills', 'knowledge'],
#  [108596, 'project management skills', 'networking'],
#  [108596, 'project management skills', 'ccna'],
#  [108596, 'project management skills', 'troubleshooting'],
#  [108596, 'project management skills', 'mcse'],
#  [108596, 'project management skills', 'unix'],
#  [108596, 'project management skills', 'solaris'],
#  [108596, 'project management skills', 'firewall'],
#  [108596, 'project management skills', 'win2k'],
#  [11372, 'development', 'java j2ee'],
#  [11372, 'development', 'html'],
#  [11372, 'development', 'jsp'],
#  [11372, 'development', 'ejb'],
#  [11372, 'development', 'coding'],
#  [11372, 'development', 'atg'],
#  [11372, 'development', 'content management'],
#  [11372, 'development', 'travel'],
#  [11372, 'development', 'merchandising'],
#  [42635, 'Primary teacher', 'Maths and science. Teaching'],
#  [42635, 'Primary teacher', 'mathematics and science. teaching'],
#  [90473, 'HR', 'Fresher'],
#  [90473, 'HR', 'Graduate'],
#  [90473, 'HR', 'mba human resource'],
#  [90473, 'HR', 'hr executive'],
#  [90473, 'HR', 'hr fresher'],
#  [90473, 'HR', 'mba recruitment'],
#  [90473, 'HR', 'mba hiring'],
#  [90473, 'HR', 'mba resourcing'],
#  [90473, 'HR', 'hr recruitment'],
#  [90473, 'HR', 'hr business development'],
#  [90473, 'HR', 'hr bdm'],
#  [90473, 'HR', 'hr marketing'],
#  [90473, 'HR', 'Recruitment'],
#  [90473, 'HR', 'Recruiter'],
#  [90473, 'HR', 'BBA'],
#  [90473, 'HR', 'MBA HR'],
#  [90473, 'HR', 'mba fresher'],
#  [90473, 'HR', 'It recruiter'],
#  [87563, 'inbound', 'copyright'],
#  [87563, 'inbound', 'metro'],
#  [87563, 'inbound', 'operations'],
#  [87563, 'inbound', 'night shift'],
#  [87563, 'inbound', 'quality assurance'],
#  [87563, 'inbound', 'quality control'],
#  [87563, 'inbound', 'call monitoring'],
#  [87563, 'inbound', 'quality audit'],
#  [87563, 'inbound', 'quality controller'],
#  [19878, 'Gas Turbine', 'Manufacturing Engineering'],
#  [45644, 'unix', 'linux'],
#  [45644, 'unix', 'aix'],
#  [45644, 'unix', 'production support'],
#  [45644, 'unix', 'vmware'],
#  [45644, 'unix', 'san'],
#  [45644, 'unix', 'performance tuning'],
#  [45644, 'unix', 'pmp'],
#  [45644, 'unix', 'backup'],
#  [45644, 'unix', 'sms'],
#  [94224, 'PPC EXECUTIVE', 'production planning control executive'],
#  [44614, 'front office executive', 'front desk executive'],
#  [44614, 'front office executive', 'foe'],
#  [44614, 'front office executive', 'front office assistant'],
#  [44614, 'front office executive', 'guest relation executive'],
#  [44614, 'front office executive', 'receptionist front office'],
#  [44614, 'front office executive', 'receptionist'],
#  [4737, 'grass', 'gis'],
#  [118512, 'Fresher', 'US Recruiting'],
#  [118512, 'Fresher', 'us staffing'],
#  [27647, 'IOS', 'RESTful applications'],
#  ...]

# %%
formatted_data = pd.DataFrame(data, columns = ['job_brief_id', 'keyword_name', 'job_title'])
formatted_data.head()
# Out:
#    job_brief_id     keyword_name             job_title
# 0          9153  capital_markets               lending
# 1          9153  capital_markets     trading_solutions
# 2          9153  capital_markets    financial_services
# 3          9153  capital_markets    investment_banking
# 4          9153  capital_markets  front_office_trading

# %%
formatted_data.to_csv("formatted_skill2vec.csv", encoding='utf-8', index=False)
